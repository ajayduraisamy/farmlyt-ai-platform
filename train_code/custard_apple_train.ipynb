# %%
from google.colab import drive
drive.mount('/content/drive')


# Install YOLO
# !pip install ultralytics

from ultralytics import YOLO

# Load model
model = YOLO("yolov8n.pt")

# Train
model.train(
    data="/content/drive/MyDrive/custard_apple_final_datasets/data.yaml",
    epochs=80,
    imgsz=640
)
# Out:
# Mounted at /content/drive
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 32.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.9/72.9 MB 19.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 824.0/824.0 kB 63.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.9/46.9 MB 35.0 MB/s eta 0:00:00
# ...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.31 🚀 Python-3.12.13 torch-2.9.0+cpu CPU (AMD EPYC 7B13)
# ...

# %%
import shutil

shutil.make_archive("custard_full_results", 'zip', "/content/runs/detect/train")
# Out:
# '/content/custard_full_results.zip'

# %%
from google.colab import files
files.download("custard_full_results.zip")

# %%
import os

base_path = "/content/drive/MyDrive/guava_final_datasets/labels"

fixed = 0

for split in ["train", "val"]:
    folder = os.path.join(base_path, split)

    for file in os.listdir(folder):
        if "healthy" in file:
            file_path = os.path.join(folder, file)

            with open(file_path, "r") as f:
                lines = f.readlines()

            new_lines = []
            for line in lines:
                parts = line.strip().split()

                if len(parts) > 0 and parts[0] == "3":
                    parts[0] = "2"   # 🔥 FIX HERE
                    fixed += 1

                new_lines.append(" ".join(parts) + "\n")

            with open(file_path, "w") as f:
                f.writelines(new_lines)

print("✅ Fixed labels:", fixed)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5053/3532594470.py in <cell line: 0>()
#       8     folder = os.path.join(base_path, split)
#       9
# ---> 10     for file in os.listdir(folder):
#      11         if "healthy" in file:
#      12             file_path = os.path.join(folder, file)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/guava_final_datasets/labels/train'
