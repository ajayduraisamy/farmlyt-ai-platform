# %%
from google.colab import drive
drive.mount('/content/drive')

# !pip install ultralytics

from ultralytics import YOLO

model = YOLO("yolov8m.pt")   # 🔥 upgrade model

model.train(
    data="/content/drive/MyDrive/tomato_100_dataset/data.yaml",
    epochs=120,              # no need 200
    imgsz=800,               # 🔥 better detail
    batch=8,                 # fits T4 GPU

    optimizer="AdamW",
    lr0=0.001,
    patience=30,

    augment=True,            # 🔥 IMPORTANT
    hsv_h=0.015,
    hsv_s=0.7,
    hsv_v=0.4,
    scale=0.5,
    translate=0.1,
    fliplr=0.5,
    mosaic=1.0,

    project="/content/drive/MyDrive/yolo_final",
    name="finals_tomato_model_v3",
    exist_ok=True
)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# Ultralytics 8.4.40 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
